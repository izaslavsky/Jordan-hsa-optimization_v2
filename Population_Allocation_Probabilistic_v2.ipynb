# %% [markdown]
# # Patient Allocation - Probabilistic Two-Step Workflow
#
# **Purpose**: Allocate population to HSAs using a probabilistic gravity model
#
# ## Two-Step Allocation Process
#
# ### Step 1: Pixel → ALL Facilities (Probabilistic)
# Instead of assigning each population pixel to ONE facility (hard assignment), this workflow
# SPLITS each pixel's population across ALL reachable facilities based on gravity model probabilities.
#
# **Gravity Model**:
# $$
# P(facility_i | pixel) = \frac{Volume_i^\alpha / Distance_i^\beta}{\sum_j Volume_j^\alpha / Distance_j^\beta}
# $$
#
# Where:
# - $\alpha = 0.75$ (facility size weight)
# - $\beta = 1.5$ (distance decay)
# - Maximum distance = 100 km
#
# ### Step 2: Facility → HSA Aggregation (Three-Case Logic)
#
# After allocating population to all 188 facilities, we aggregate to HSAs using:
#
# | Case | Condition | Assignment |
# |------|-----------|------------|
# | **Case 1** | Facility inside exactly 1 HSA | 100% to that HSA |
# | **Case 2** | Facility outside all HSAs | Assign to nearest HSA anchor within 100km |
# | **Case 3** | Facility inside 2+ overlapping HSAs | Proportional using gravity model ($Volume^\alpha / Distance^\beta$) |
#
# Facilities beyond 100km from any HSA anchor are excluded and reported.
#
# ---

# %%
# ── BOUNDARY VERSION SELECTOR ──────────────────────────────────────────────
# Choose which HSA boundary bundle to use for this analysis.
# Must match a bundle produced by HSA_FINAL.ipynb.
#   'v6'  — original greedy algorithm (no post-selection corrections)
#   'v7'  — + anchor upgrade/demotion + major-orphan promotion
#   'v8'  — + satellite bubble boundaries
BOUNDARY_VERSION = "v7"   # change as needed
# ────────────────────────────────────────────────────────────────────────────

# %%
# %load_ext autoreload
# %autoreload 2

# ============================================================================
# CONFIGURATION
# ============================================================================

from pathlib import Path
import os
import pandas as pd
import geopandas as gpd
import numpy as np
from population_allocation import PopulationAllocator, allocate_population_probabilistic

# Directories
DATA_DIR = Path(os.environ.get("HSA_DATA_DIR", "data"))
OUT_DIR = Path(os.environ.get("HSA_OUT_DIR", os.environ.get("PIPELINE_OUT_DIR", "out")))
OUT_DIR.mkdir(parents=True, exist_ok=True)

# ============================================================================
# SELECT NETWORK AND HSA MODE
# ============================================================================
NETWORK = "INF"  # Options: 'INF' or 'NCD'

# Available HSA modes from HSA_v7_FINAL.ipynb:
#   - 'fewest': Minimum number of HSAs
#   - 'footprint': Maximum geographic diversity
#   - 'distance': Minimize travel distance
#   - 'governorate_tau_coverage': 90% coverage per governorate
#   - 'governorate_fewest': One anchor per governorate + minimize total

HSA_MODE = "footprint"  # <- CHANGE THIS to select your HSA mode

# Population raster
POP_RASTER = DATA_DIR / "jor_ppp_2020_UNadj.tif"

# ============================================================================
# GRAVITY MODEL PARAMETERS
# ============================================================================
GRAVITY_PARAMS = {
    'alpha': 0.75,          # Facility size weight
    'beta': 1.5,            # Distance decay exponent
    'max_distance_km': 100, # Absolute ceiling; Case 2 fallback guard is stricter
    'sample_rate': 1        # Set to 1 for production, >1 for testing
}

FALLBACK_GUARD_PARAMS = {
    'fallback_radius_multiplier': 1.5,
    'fallback_min_distance_km': 30.0,
    'major_facility_pop_threshold': 25000.0,
    'major_facility_volume_threshold': None,
    'major_facility_volume_quantile': 0.80,
    'require_same_governorate_for_major': True,
}

print("="*80)
print("PROBABILISTIC PATIENT ALLOCATION CONFIGURATION")
print("="*80)
print(f"Network: {NETWORK}")
print(f"HSA Mode: {HSA_MODE}")
print(f"Population Raster: {POP_RASTER.name}")
print(f"\nGravity Model Parameters:")
for key, val in GRAVITY_PARAMS.items():
    print(f"  {key}: {val}")
print(f"\nFallback Guard Parameters:")
for key, val in FALLBACK_GUARD_PARAMS.items():
    print(f"  {key}: {val}")
print("\nAllocation Mode: PROBABILISTIC (two-step)")
print("="*80)
# Out:
# ================================================================================
# PROBABILISTIC PATIENT ALLOCATION CONFIGURATION
# ================================================================================
# Network: INF
# HSA Mode: footprint
# Population Raster: jor_ppp_2020_UNadj.tif
#
# Gravity Model Parameters:
#   alpha: 0.75
#   beta: 1.5
#   max_distance_km: 100
#   sample_rate: 1
#
# Fallback Guard Parameters:
#   fallback_radius_multiplier: 1.5
#   fallback_min_distance_km: 30.0
#   major_facility_pop_threshold: 25000.0
#   major_facility_volume_threshold: None
#   major_facility_volume_quantile: 0.8
#   require_same_governorate_for_major: True
#
# Allocation Mode: PROBABILISTIC (two-step)
# ================================================================================

# %% [markdown]
# ## 1. Load Data

# %%
# Load HSA boundaries (output from HSA_v7_FINAL.ipynb)
hsa_file = OUT_DIR / f"{NETWORK}_{HSA_MODE}_hsas_{BOUNDARY_VERSION}.geojson"

if not hsa_file.exists():
    raise FileNotFoundError(
        f"HSA file not found: {hsa_file}\n"
        f"Please run HSA_v7_FINAL.ipynb first to generate HSA boundaries for mode '{HSA_MODE}'."
    )

hsas = gpd.read_file(hsa_file)
print(f"Loaded {len(hsas)} HSA anchors from {hsa_file.name}")

# Display HSA anchors
print("\nHSA Anchor Facilities:")
for idx, row in hsas.iterrows():
    fac_name = row.get('HealthFacility', row.get('FacilityName', f'Facility_{idx}'))
    radius = row.get('service_radius_km', row.get('initial_radius_km', 'N/A'))
    print(f"  {idx+1}. {fac_name} (radius: {radius:.1f} km)")
# Out:
# Loaded 19 HSA anchors from INF_footprint_hsas_v7.geojson
#
# HSA Anchor Facilities:
#   1. Al-Basheer Hospital (radius: 12.0 km)
#   2. Princess Raya Hospital (radius: 19.4 km)
#   3. AL-Shuneh Hospital (radius: 18.0 km)
#   4. AL-Nadeem Hospital (radius: 17.6 km)
#   5. AL-Zarqa Hospital (radius: 9.3 km)
#   6. Khazzan Primary Center (radius: 16.4 km)
#   7. Jarash Hospital (radius: 16.3 km)
#   8. Al-Yarmouk Hospital (radius: 16.2 km)
#   9. Dr. Jamel Al-Totanji Hospital (radius: 8.9 km)
#   10. AL-Ramtha Hospital (radius: 15.9 km)
#   11. Al-Mafraq Gynecology and Pediatrics Hospital (radius: 15.9 km)
#   12. Al-Karak Hospital (radius: 15.8 km)
#   13. Mabroukeh Primary Center (radius: 15.4 km)
#   14. Tafilah Governmental Hospital (radius: 15.1 km)
#   15. Al Hussain New Salt Hospital (radius: 14.7 km)
#   16. Prince Hashem Primary Center (radius: 14.6 km)
#   17. Jadaa Primary Center (radius: 14.4 km)
#   18. Maan Hospital (radius: 15.8 km)
#   19. Queen Rania Hospital (radius: 15.8 km)

# %%
# Load ALL facilities (not just HSA anchors)
facilities_csv = OUT_DIR / f"{NETWORK}_Facilities_Climate_Features_with_clusters.csv"

if not facilities_csv.exists():
    raise FileNotFoundError(
        f"Facilities file not found: {facilities_csv}\n"
        f"Please ensure the climate features CSV is in the output directory."
    )

all_facilities_df = pd.read_csv(facilities_csv)

# Normalize whitespace in facility names
if 'FacilityName' in all_facilities_df.columns:
    all_facilities_df['HealthFacility'] = all_facilities_df['FacilityName'].str.replace(r'\s+', ' ', regex=True).str.strip()
elif 'HealthFacility' in all_facilities_df.columns:
    all_facilities_df['HealthFacility'] = all_facilities_df['HealthFacility'].str.replace(r'\s+', ' ', regex=True).str.strip()

# Load diagnosis counts for patient volumes
diagnosis_csv = OUT_DIR / f"{NETWORK}_{HSA_MODE}_diagnosis_counts_pivot.csv"

if diagnosis_csv.exists():
    diagnosis_df = pd.read_csv(diagnosis_csv)
    diagnosis_df['healthfacility'] = diagnosis_df['healthfacility'].str.replace(r'\s+', ' ', regex=True).str.strip()
    
    merge_cols = ['healthfacility', 'total_diagnoses']
    for optional_col in ['healthfacilitytype', 'governorate']:
        if optional_col in diagnosis_df.columns:
            merge_cols.append(optional_col)

    all_facilities_df = all_facilities_df.merge(
        diagnosis_df[merge_cols],
        left_on='HealthFacility',
        right_on='healthfacility',
        how='left'
    )
    all_facilities_df['Total'] = all_facilities_df['total_diagnoses'].fillna(1000)  # Default for missing
else:
    print(f"WARNING: Diagnosis counts not found at {diagnosis_csv}")
    print("  Using uniform facility weights (Total = 1000 for all facilities)")
    all_facilities_df['Total'] = 1000

# Create GeoDataFrame
all_facilities = gpd.GeoDataFrame(
    all_facilities_df,
    geometry=gpd.points_from_xy(all_facilities_df['lon'], all_facilities_df['lat']),
    crs='EPSG:4326'
)

print(f"\nLoaded {len(all_facilities)} total facilities")
print(f"  Facilities with volume > 0: {(all_facilities['Total'] > 0).sum()}")
print(f"  Total patient volume: {all_facilities['Total'].sum():,.0f}")
# Out:
# Loaded 188 total facilities
#   Facilities with volume > 0: 188
#   Total patient volume: 66,876

# %% [markdown]
# ## 2. Step 1: Probabilistic Allocation to ALL Facilities
#
# Each population pixel is allocated to ALL reachable facilities based on gravity model probabilities.

# %%
# Initialize allocator with ALL facilities
print("Initializing PopulationAllocator with ALL facilities...")
allocator = PopulationAllocator(
    pop_raster_path=str(POP_RASTER),
    facilities_gdf=all_facilities,
    params=GRAVITY_PARAMS
)

print(f"\n  Allocating to {len(all_facilities)} facilities (not just {len(hsas)} HSA anchors)")
# Out:
# Initializing PopulationAllocator with ALL facilities...
# PopulationAllocator initialized:
#   Facilities: 188
#   Parameters: alpha=0.75, beta=1.5, max_dist=100km
#   Spatial index: KD-Tree built for fast lookups
#   Facility lon range: [35.00, 36.31]
#   Facility lat range: [29.52, 32.71]
#
#   Allocating to 188 facilities (not just 19 HSA anchors)

# %%
# Run vectorized probabilistic allocation
print("\nRunning probabilistic allocation...")
print("  (This allocates each pixel's population to ALL reachable facilities)")

facility_allocations, pixel_allocations = allocator.allocate_all_pixels_probabilistic_vectorized()

print(f"\nFacility allocation summary:")
print(f"  Facilities with allocated population: {len(facility_allocations)}")
print(f"  Total allocated population: {facility_allocations['allocated_population'].sum():,.0f}")

# Show top 15 facilities
print(f"\nTop 15 facilities by allocated population:")
print(facility_allocations.head(15).to_string(index=False))

print(f"\nPixel allocations tracked: {len(pixel_allocations):,}")
# Out:
# Running probabilistic allocation...
#   (This allocates each pixel's population to ALL reachable facilities)
#
# Allocating population pixels to facilities (VECTORIZED)...
#   Raster size: 5018 x 5214 = 26,163,852 pixels
#   Populated sampled pixels: 12,091,883
#   Total sampled population: 10,203,140
#   Batches: 242 (batch_size=50,000)
#     Progress:   1.7% | 200,000 pixels | 0.0% population allocated
#     Progress:   3.3% | 400,000 pixels | 0.0% population allocated
#     Progress:   5.0% | 600,000 pixels | 0.0% population allocated
#     Progress:   6.6% | 800,000 pixels | 0.8% population allocated
#     Progress:   8.3% | 1,000,000 pixels | 3.5% population allocated
#     Progress:   9.9% | 1,200,000 pixels | 9.9% population allocated
#     Progress:  11.6% | 1,400,000 pixels | 14.7% population allocated
#     Progress:  13.2% | 1,600,000 pixels | 17.2% population allocated
#     Progress:  14.9% | 1,800,000 pixels | 19.2% population allocated
#     Progress:  16.5% | 2,000,000 pixels | 21.6% population allocated
#     Progress:  18.2% | 2,200,000 pixels | 24.1% population allocated
#     Progress:  19.8% | 2,400,000 pixels | 26.3% population allocated
#     Progress:  21.5% | 2,600,000 pixels | 27.6% population allocated
#     Progress:  23.2% | 2,800,000 pixels | 28.6% population allocated
#     Progress:  24.8% | 3,000,000 pixels | 29.8% population allocated
#     Progress:  26.5% | 3,200,000 pixels | 31.6% population allocated
#     Progress:  28.1% | 3,400,000 pixels | 36.4% population allocated
#     Progress:  29.8% | 3,600,000 pixels | 43.5% population allocated
#     Progress:  31.4% | 3,800,000 pixels | 55.1% population allocated
#     Progress:  33.1% | 4,000,000 pixels | 69.1% population allocated
#     Progress:  34.7% | 4,200,000 pixels | 78.9% population allocated
#     Progress:  36.4% | 4,400,000 pixels | 84.1% population allocated
#     Progress:  38.0% | 4,600,000 pixels | 86.6% population allocated
#     Progress:  39.7% | 4,800,000 pixels | 87.6% population allocated
#     Progress:  41.4% | 5,000,000 pixels | 89.3% population allocated
#     Progress:  43.0% | 5,200,000 pixels | 89.9% population allocated
#     Progress:  44.7% | 5,400,000 pixels | 90.2% population allocated
#     Progress:  46.3% | 5,600,000 pixels | 90.6% population allocated
#     Progress:  48.0% | 5,800,000 pixels | 90.8% population allocated
#     Progress:  49.6% | 6,000,000 pixels | 91.3% population allocated
#     Progress:  51.3% | 6,200,000 pixels | 91.7% population allocated
#     Progress:  52.9% | 6,400,000 pixels | 92.6% population allocated
#     Progress:  54.6% | 6,600,000 pixels | 93.6% population allocated
#     Progress:  56.2% | 6,800,000 pixels | 94.3% population allocated
#     Progress:  57.9% | 7,000,000 pixels | 94.6% population allocated
#     Progress:  59.5% | 7,200,000 pixels | 94.7% population allocated
#     Progress:  61.2% | 7,400,000 pixels | 95.3% population allocated
#     Progress:  62.9% | 7,600,000 pixels | 95.5% population allocated
#     Progress:  64.5% | 7,800,000 pixels | 95.7% population allocated
#     Progress:  66.2% | 8,000,000 pixels | 95.9% population allocated
#     Progress:  67.8% | 8,200,000 pixels | 96.0% population allocated
#     Progress:  69.5% | 8,400,000 pixels | 96.1% population allocated
#     Progress:  71.1% | 8,600,000 pixels | 96.2% population allocated
#     Progress:  72.8% | 8,800,000 pixels | 96.3% population allocated
#     Progress:  74.4% | 9,000,000 pixels | 96.4% population allocated
#     Progress:  76.1% | 9,200,000 pixels | 96.5% population allocated
#     Progress:  77.7% | 9,400,000 pixels | 96.8% population allocated
#     Progress:  79.4% | 9,600,000 pixels | 97.0% population allocated
#     Progress:  81.0% | 9,800,000 pixels | 97.4% population allocated
#     Progress:  82.7% | 10,000,000 pixels | 97.5% population allocated
#     Progress:  84.4% | 10,200,000 pixels | 97.6% population allocated
#     Progress:  86.0% | 10,400,000 pixels | 97.6% population allocated
#     Progress:  87.7% | 10,600,000 pixels | 97.7% population allocated
#     Progress:  89.3% | 10,800,000 pixels | 97.7% population allocated
#     Progress:  91.0% | 11,000,000 pixels | 97.8% population allocated
#     Progress:  92.6% | 11,200,000 pixels | 97.9% population allocated
#     Progress:  94.3% | 11,400,000 pixels | 98.1% population allocated
#     Progress:  95.9% | 11,600,000 pixels | 99.1% population allocated
#     Progress:  97.6% | 11,800,000 pixels | 99.4% population allocated
#     Progress:  99.2% | 12,000,000 pixels | 99.8% population allocated
#     Progress: 100.0% | 12,091,883 pixels | 99.8% population allocated
#
#   Vectorized allocation complete:
#     Total population: 10,203,140
#     Allocated population: 10,179,256 (99.8%)
#     Unallocated population: 23,884 (0.2%)
#     Pixels processed: 12,091,883
#     Facilities receiving allocation: 188
#     Sum of facility allocations: 10,179,256
#     Pixel allocations tracked: 7,530,641
#
# Facility allocation summary:
#   Facilities with allocated population: 188
#   Total allocated population: 10,179,256
#
# Top 15 facilities by allocated population:
#                           facility_id  allocated_population
#                   Al-Basheer Hospital         396742.157848
#               Princess Rahma Hospital         313426.565748
#                Princess Raya Hospital         231499.719475
# Prince Faisal Bin Al-Hussein Hospital         215654.433464
#   Princess Basma Comprehensive Center         209829.588257
#     North Hashmi Comprehensive Center         190190.030987
#                Prince Hamzah Hospital         189876.847054
#    Dhaheyat Al-Hussein Primary Center         185325.964350
#              Al-Theraa Primary Center         173946.450135
#               Princess Basma Hospital         173236.646651
#                     AL-Zarqa Hospital         166412.115485
#            Amman Comprehensive Center         149996.439703
#        Tabarbour Comprehensive Center         142863.158002
#                Khazzan Primary Center         142006.777288
#         Luaibdeh Comprehensive Center         135134.983792
#
# Pixel allocations tracked: 7,530,641

# %% [markdown]
# ## 3. Step 2: Aggregate Facilities to HSAs
#
# Now aggregate the facility-level populations to HSAs using three-case logic:
# - **Case 1**: Facility inside exactly 1 HSA → 100% to that HSA
# - **Case 2**: Facility outside all HSAs → nearest HSA anchor within 100km
# - **Case 3**: Facility inside 2+ overlapping HSAs → proportional using gravity model (Volume^α / Distance^β)

# %%
# Aggregate facilities to HSAs using three-case logic (with gravity model for Case 3)
hsa_summary, facility_assignments = allocator.aggregate_facilities_to_hsas(
    facility_allocations,
    hsas,
    all_facilities,
    network_type=NETWORK,
    optimization_mode=HSA_MODE,
    max_assignment_distance_km=GRAVITY_PARAMS['max_distance_km'],
    fallback_radius_multiplier=FALLBACK_GUARD_PARAMS['fallback_radius_multiplier'],
    fallback_min_distance_km=FALLBACK_GUARD_PARAMS['fallback_min_distance_km'],
    major_facility_pop_threshold=FALLBACK_GUARD_PARAMS['major_facility_pop_threshold'],
    major_facility_volume_threshold=FALLBACK_GUARD_PARAMS['major_facility_volume_threshold'],
    major_facility_volume_quantile=FALLBACK_GUARD_PARAMS['major_facility_volume_quantile'],
    require_same_governorate_for_major=FALLBACK_GUARD_PARAMS['require_same_governorate_for_major'],
    alpha=GRAVITY_PARAMS['alpha'],
    beta=GRAVITY_PARAMS['beta']
)
# Out:
# ================================================================================
# AGGREGATING FACILITIES TO HSAs (THREE-CASE LOGIC)
# ================================================================================
#   Gravity model parameters: alpha=0.75, beta=1.5
#   Case 2 fallback guard: max=100.0km, radius_multiplier=1.50, min_allowance=30.0km, major_pop_threshold=25,000
#   Major facility volume threshold: 513
#
# Facility Assignment Summary:
#   Case 1 (Inside 1 HSA):            155 facilities
#   Case 2 (Outside, assigned):         9 facilities
#   Case 3 (Overlapping, proportional):   23 facilities
#   EXCLUDED (no admissible fallback):    1 facilities
#   Total:                            188 facilities
#
# Excluded Facilities (no admissible fallback; anchor promotion needed):
#   Count: 1
#   Total excluded population: 702
#     - Swaqa Correctional Primary: 702 people (nearest: Jadaa Primary Center, 30.8km)
#
# HSA Population Summary:
# HSA Anchor                                         Population   Facilities
# ---------------------------------------------------------------------------
#   Al-Basheer Hospital                               4,085,364           36
#   AL-Zarqa Hospital                                 1,229,143           14
#   Princess Raya Hospital                            1,140,072            5
#   Al Hussain New Salt Hospital                        690,864           15
#   Jarash Hospital                                     468,590           10
#   AL-Ramtha Hospital                                  405,381           12
#   Al-Karak Hospital                                   393,082           30
#   Al-Mafraq Gynecology and Pediatrics Hospital         369,366           12
#   Dr. Jamel Al-Totanji Hospital                       276,345            8
#   AL-Nadeem Hospital                                  258,821           12
#   Khazzan Primary Center                              182,642            4
#   AL-Shuneh Hospital                                  133,795            2
#   Tafilah Governmental Hospital                       113,330            3
#   Al-Yarmouk Hospital                                 104,602            3
#   Maan Hospital                                        93,962            2
#   Queen Rania Hospital                                 90,279            2
#   Mabroukeh Primary Center                             82,015            2
#   Prince Hashem Primary Center                         35,722            4
#   Jadaa Primary Center                                 25,179           11
# ---------------------------------------------------------------------------
#   TOTAL                                            10,178,554          187
#
# ================================================================================

# %%
# Display facility assignment breakdown by case
print("\nFacility Assignment Breakdown by Case:")
case_summary = facility_assignments.groupby('assignment_case').agg(
    count=('facility_id', 'count'),
    total_population=('allocated_population', 'sum')
).reset_index()
case_summary['pct_facilities'] = (case_summary['count'] / case_summary['count'].sum() * 100).round(1)
case_summary['pct_population'] = (case_summary['total_population'] / case_summary['total_population'].sum() * 100).round(1)
print(case_summary.to_string(index=False))
# Out:
# Facility Assignment Breakdown by Case:
#                       assignment_case  count  total_population  pct_facilities  pct_population
#                  Case 1: Inside 1 HSA    155      8.928356e+06            82.4            87.7
#    Case 2: Outside all HSAs (nearest)      9      1.828006e+05             4.8             1.8
# Case 3: Inside 2+ HSAs (proportional)     23      1.067397e+06            12.2            10.5
#   EXCLUDED: Requires anchor promotion      1      7.017931e+02             0.5             0.0

# %% [markdown]
# ## 4. Save Results

# %%
# Save HSA population summary (PRIMARY OUTPUT)
hsa_output = OUT_DIR / f"{NETWORK}_{HSA_MODE}_hsa_populations_probabilistic_{BOUNDARY_VERSION}.csv"
hsa_summary.to_csv(hsa_output, index=False)
print(f"Saved HSA population summary: {hsa_output}")

# Save facility allocations from pixels
fac_alloc_output = OUT_DIR / f"{NETWORK}_{HSA_MODE}_facility_allocations_probabilistic_{BOUNDARY_VERSION}.csv"
facility_allocations.to_csv(fac_alloc_output, index=False)
print(f"Saved facility allocations: {fac_alloc_output}")

# Save facility-to-HSA assignments (shows three-case logic)
fac_assign_output = OUT_DIR / f"{NETWORK}_{HSA_MODE}_facility_hsa_assignments_{BOUNDARY_VERSION}.csv"
facility_assignments.to_csv(fac_assign_output, index=False)
print(f"Saved facility-to-HSA assignments: {fac_assign_output}")

# Save pixel-level allocations (two formats for compatibility)
pixel_output = OUT_DIR / f"pixel_allocations_{NETWORK}_{HSA_MODE}_{BOUNDARY_VERSION}.csv"
pixel_allocations.to_csv(pixel_output, index=False)
print(f"Saved pixel allocations: {pixel_output}")

# Also save as allocation_details.csv (expected by downstream scripts)
details_output = OUT_DIR / f"{NETWORK}_{HSA_MODE}_allocation_details_{BOUNDARY_VERSION}.csv"
pixel_allocations.to_csv(details_output, index=False)
print(f"Saved allocation details: {details_output}")
print(f"  File size: {details_output.stat().st_size / (1024*1024):.1f} MB")
# Out:
# Saved HSA population summary: out/INF_footprint_hsa_populations_probabilistic_v7.csv
# Saved facility allocations: out/INF_footprint_facility_allocations_probabilistic_v7.csv
# Saved facility-to-HSA assignments: out/INF_footprint_facility_hsa_assignments_v7.csv
# Saved pixel allocations: out/pixel_allocations_INF_footprint_v7.csv
# Saved allocation details: out/INF_footprint_allocation_details_v7.csv
#   File size: 744.3 MB

# %% [markdown]
# ## 5. Paper Tables

# %%
# TABLE 1: HSA Population Summary
print("\n" + "="*80)
print("TABLE 1: HSA Population Summary (Probabilistic Allocation)")
print("="*80)
print(f"Network: {NETWORK} | HSA Mode: {HSA_MODE}")
print("-"*80)

table1 = hsa_summary[['anchor_id', 'anchor_name', 'allocated_patients', 'num_facilities_in_hsa']].copy()
table1['allocated_patients'] = table1['allocated_patients'].apply(lambda x: f"{x:,.0f}")
table1.columns = ['Rank', 'HSA Anchor', 'Allocated Population', 'Facilities']
print(table1.to_string(index=False))

print("-"*80)
total_pop = hsa_summary['allocated_patients'].sum()
total_fac = hsa_summary['num_facilities_in_hsa'].sum()
print(f"{'TOTAL':<6} {'':<45} {total_pop:>20,.0f} {total_fac:>12}")
print("="*80)
# Out:
# ================================================================================
# TABLE 1: HSA Population Summary (Probabilistic Allocation)
# ================================================================================
# Network: INF | HSA Mode: footprint
# --------------------------------------------------------------------------------
#  Rank                                   HSA Anchor Allocated Population  Facilities
#     1                          Al-Basheer Hospital            4,085,364          36
#     2                            AL-Zarqa Hospital            1,229,143          14
#     3                       Princess Raya Hospital            1,140,072           5
#     4                 Al Hussain New Salt Hospital              690,864          15
#     5                              Jarash Hospital              468,590          10
#     6                           AL-Ramtha Hospital              405,381          12
#     7                            Al-Karak Hospital              393,082          30
#     8 Al-Mafraq Gynecology and Pediatrics Hospital              369,366          12
#     9                Dr. Jamel Al-Totanji Hospital              276,345           8
#    10                           AL-Nadeem Hospital              258,821          12
#    11                       Khazzan Primary Center              182,642           4
#    12                           AL-Shuneh Hospital              133,795           2
#    13                Tafilah Governmental Hospital              113,330           3
#    14                          Al-Yarmouk Hospital              104,602           3
#    15                                Maan Hospital               93,962           2
#    16                         Queen Rania Hospital               90,279           2
#    17                     Mabroukeh Primary Center               82,015           2
#    18                 Prince Hashem Primary Center               35,722           4
#    19                         Jadaa Primary Center               25,179          11
# --------------------------------------------------------------------------------
# TOTAL                                                          10,178,554          187
# ================================================================================

# %%
# TABLE 2: Facility Assignment Case Distribution
print("\n" + "="*80)
print("TABLE 2: Facility Assignment Case Distribution")
print("="*80)

case_table = facility_assignments.groupby('assignment_case').agg(
    facilities=('facility_id', 'count'),
    population=('allocated_population', 'sum')
).reset_index()

total_fac = case_table['facilities'].sum()
total_pop = case_table['population'].sum()

case_table['pct_facilities'] = (case_table['facilities'] / total_fac * 100).round(1)
case_table['pct_population'] = (case_table['population'] / total_pop * 100).round(1)
case_table['population'] = case_table['population'].apply(lambda x: f"{x:,.0f}")

print(case_table.to_string(index=False))
print("="*80)
# Out:
# ================================================================================
# TABLE 2: Facility Assignment Case Distribution
# ================================================================================
#                       assignment_case  facilities population  pct_facilities  pct_population
#                  Case 1: Inside 1 HSA         155  8,928,356            82.4            87.7
#    Case 2: Outside all HSAs (nearest)           9    182,801             4.8             1.8
# Case 3: Inside 2+ HSAs (proportional)          23  1,067,397            12.2            10.5
#   EXCLUDED: Requires anchor promotion           1        702             0.5             0.0
# ================================================================================

# %%
# TABLE 3: Top 20 Facilities by Allocated Population
print("\n" + "="*80)
print("TABLE 3: Top 20 Facilities by Allocated Population")
print("="*80)

top20 = facility_assignments.nlargest(20, 'allocated_population')[[
    'facility_id', 'allocated_population', 'assignment_case', 'primary_hsa'
]].copy()
top20['allocated_population'] = top20['allocated_population'].apply(lambda x: f"{x:,.0f}")
top20.columns = ['Facility', 'Population', 'Assignment Case', 'Primary HSA']
print(top20.to_string(index=False))
print("="*80)
# Out:
# ================================================================================
# TABLE 3: Top 20 Facilities by Allocated Population
# ================================================================================
#                              Facility Population      Assignment Case            Primary HSA
#                   Al-Basheer Hospital    396,742 Case 1: Inside 1 HSA    Al-Basheer Hospital
#               Princess Rahma Hospital    313,427 Case 1: Inside 1 HSA Princess Raya Hospital
#                Princess Raya Hospital    231,500 Case 1: Inside 1 HSA Princess Raya Hospital
# Prince Faisal Bin Al-Hussein Hospital    215,654 Case 1: Inside 1 HSA      AL-Zarqa Hospital
#   Princess Basma Comprehensive Center    209,830 Case 1: Inside 1 HSA    Al-Basheer Hospital
#     North Hashmi Comprehensive Center    190,190 Case 1: Inside 1 HSA    Al-Basheer Hospital
#                Prince Hamzah Hospital    189,877 Case 1: Inside 1 HSA    Al-Basheer Hospital
#    Dhaheyat Al-Hussein Primary Center    185,326 Case 1: Inside 1 HSA    Al-Basheer Hospital
#              Al-Theraa Primary Center    173,946 Case 1: Inside 1 HSA    Al-Basheer Hospital
#               Princess Basma Hospital    173,237 Case 1: Inside 1 HSA Princess Raya Hospital
#                     AL-Zarqa Hospital    166,412 Case 1: Inside 1 HSA      AL-Zarqa Hospital
#            Amman Comprehensive Center    149,996 Case 1: Inside 1 HSA    Al-Basheer Hospital
#        Tabarbour Comprehensive Center    142,863 Case 1: Inside 1 HSA    Al-Basheer Hospital
#                Khazzan Primary Center    142,007 Case 1: Inside 1 HSA Khazzan Primary Center
#         Luaibdeh Comprehensive Center    135,135 Case 1: Inside 1 HSA    Al-Basheer Hospital
#            Naser Comprehensive Center    130,595 Case 1: Inside 1 HSA    Al-Basheer Hospital
#                    AL-Nadeem Hospital    128,332 Case 1: Inside 1 HSA     AL-Nadeem Hospital
#               Istiqlal Primary Center    125,140 Case 1: Inside 1 HSA    Al-Basheer Hospital
#                Natheef Primary Center    124,838 Case 1: Inside 1 HSA    Al-Basheer Hospital
#            Jufeh Comprehensive Center    121,401 Case 1: Inside 1 HSA    Al-Basheer Hospital
# ================================================================================

# %%
# Validation: Compare with raster total
import rasterio

with rasterio.open(POP_RASTER) as src:
    pop_data = src.read(1, masked=True)
    total_pop_raster = float(pop_data.sum())

total_hsa_pop = hsa_summary['allocated_patients'].sum()
excluded_pop = facility_assignments[facility_assignments['excluded']]['allocated_population'].sum()
total_facility_pop = facility_allocations['allocated_population'].sum()

print("\n" + "="*80)
print("VALIDATION: Population Coverage")
print("="*80)
print(f"Total population in raster:     {total_pop_raster:>15,.0f}")
print(f"Total allocated to facilities:  {total_facility_pop:>15,.0f} ({total_facility_pop/total_pop_raster*100:.1f}%)")
print(f"Total assigned to HSAs:         {total_hsa_pop:>15,.0f} ({total_hsa_pop/total_pop_raster*100:.1f}%)")
print(f"Excluded (beyond max dist):     {excluded_pop:>15,.0f} ({excluded_pop/total_pop_raster*100:.2f}%)")
print("="*80)
# Out:
# ================================================================================
# VALIDATION: Population Coverage
# ================================================================================
# Total population in raster:          10,203,140
# Total allocated to facilities:       10,179,256 (99.8%)
# Total assigned to HSAs:              10,178,554 (99.8%)
# Excluded (beyond max dist):                 702 (0.01%)
# ================================================================================

# %%
print("\n" + "="*80)
print("PROBABILISTIC ALLOCATION COMPLETE")
print("="*80)
print(f"\nOutput files saved to {OUT_DIR}:")
print(f"  - {hsa_output.name}")
print(f"  - {fac_alloc_output.name}")
print(f"  - {fac_assign_output.name}")
print(f"  - {pixel_output.name} (for downstream compatibility)")
# Out:
# ================================================================================
# PROBABILISTIC ALLOCATION COMPLETE
# ================================================================================
#
# Output files saved to out:
#   - INF_footprint_hsa_populations_probabilistic_v7.csv
#   - INF_footprint_facility_allocations_probabilistic_v7.csv
#   - INF_footprint_facility_hsa_assignments_v7.csv
#   - pixel_allocations_INF_footprint_v7.csv (for downstream compatibility)

# %%
# AUTO_NOTEBOOK_SUMMARY_V1
from pathlib import Path
from datetime import datetime
import os
import json

NOTEBOOK_NAME = "Population_Allocation_Probabilistic_v2"
NETWORK = globals().get('NETWORK', os.environ.get('NETWORK', 'INF'))
HSA_MODE = globals().get('HSA_MODE', os.environ.get('HSA_MODE', ''))

suffix = f"{NETWORK}_{HSA_MODE}" if HSA_MODE else f"{NETWORK}"

out_root = Path(globals().get('OUT_DIR', globals().get('OUT_ROOT', os.environ.get('HSA_OUT_DIR', os.environ.get('PIPELINE_OUT_DIR', "out")))))
summary_dir = out_root / 'textresults'
summary_dir.mkdir(parents=True, exist_ok=True)
BOUNDARY_VERSION = globals().get('BOUNDARY_VERSION', os.environ.get('BOUNDARY_VERSION', os.environ.get('PIPELINE_VERSION', 'v7')))
summary_path = summary_dir / f"{NOTEBOOK_NAME}_{suffix}_{BOUNDARY_VERSION}_results.md"

files = [p for p in out_root.rglob('*') if p.is_file() and p.suffix.lower() in {'.csv', '.json', '.md', '.txt', '.png', '.pdf', '.geojson', '.parquet'}]
files.sort(key=lambda p: p.stat().st_mtime, reverse=True)
important = files[:120]

NL = "\n"

blocks = []
blocks.append(f"# Notebook Results: {NOTEBOOK_NAME}")

meta = [
    f"- Generated: {datetime.now().isoformat(timespec='seconds')}",
    f"- Network: {NETWORK}",
]
if HSA_MODE:
    meta.append(f"- HSA mode: {HSA_MODE}")
blocks.append(NL.join(meta))

file_lines = ['## Important Output Files', '']
for p in important:
    file_lines.append(f"- `{p}`")
blocks.append(NL.join(file_lines))

nb_path = Path(f"{NOTEBOOK_NAME}.ipynb")
if nb_path.exists():
    try:
        nb_data = json.loads(nb_path.read_text())
        blocks.append('## Displayed Cell Outputs')

        for idx, cell in enumerate(nb_data.get('cells', []), start=1):
            if cell.get('cell_type') != 'code':
                continue
            outputs = cell.get('outputs', []) or []
            if not outputs:
                continue

            blocks.append(f"### Cell {idx}")

            for out in outputs:
                otype = out.get('output_type')

                if otype == 'stream':
                    text = ''.join(out.get('text', [])) if isinstance(out.get('text', []), list) else str(out.get('text', ''))
                    text = text.rstrip()
                    if text:
                        blocks.append("```text" + NL + text + NL + "```")

                elif otype in ('execute_result', 'display_data'):
                    data = out.get('data', {})
                    if 'text/markdown' in data:
                        md = ''.join(data['text/markdown']) if isinstance(data['text/markdown'], list) else str(data['text/markdown'])
                        md = md.rstrip()
                        if md:
                            blocks.append(md)
                    elif 'text/plain' in data:
                        txt = ''.join(data['text/plain']) if isinstance(data['text/plain'], list) else str(data['text/plain'])
                        txt = txt.rstrip()
                        if txt:
                            blocks.append("```text" + NL + txt + NL + "```")
                    elif 'text/html' in data:
                        html = ''.join(data['text/html']) if isinstance(data['text/html'], list) else str(data['text/html'])
                        html = html.rstrip()
                        if html:
                            blocks.append("```html" + NL + html + NL + "```")
                    elif 'image/png' in data or 'image/jpeg' in data:
                        blocks.append('_[Image output omitted in text summary]_')

                elif otype == 'error':
                    tb = out.get('traceback', []) or []
                    if tb:
                        err = NL.join(str(t) for t in tb)
                    else:
                        err = f"{out.get('ename', 'Error')}: {out.get('evalue', '')}"
                    blocks.append("```text" + NL + err + NL + "```")

    except Exception as e:
        blocks.append('## Displayed Cell Outputs')
        blocks.append(f"Could not parse notebook outputs: {e}")

summary = (NL + NL).join(b for b in blocks if b and str(b).strip()) + NL
summary_path.write_text(summary)
print(f"Saved notebook summary: {summary_path}")
# Out:
# Saved notebook summary: out/textresults/Population_Allocation_Probabilistic_v2_INF_footprint_v7_results.md
